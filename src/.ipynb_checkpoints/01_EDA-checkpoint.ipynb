# %% [markdown]
# # 라이브러리 임포트

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 문제 정의
# - 농구선수의 경기기록을 바탕으로 그 선수의 포지션을 예측해보는 모델 생성.

# %% [markdown]
# # 데이터 수집

# %%
#데이터를 수집 
df = pd.read_csv('data/csv/basketball_stat.csv')
df
# Out:
#               Player Pos   3P   2P   TRB  AST  STL  BLK
# 0       Alex Abrines  SG  1.4  0.6   1.3  0.6  0.5  0.1
# 1       Steven Adams   C  0.0  4.7   7.7  1.1  1.1  1.0
# 2      Alexis Ajinca   C  0.0  2.3   4.5  0.3  0.5  0.6
# 3     Chris Andersen   C  0.0  0.8   2.6  0.4  0.4  0.6
# 4        Will Barton  SG  1.5  3.5   4.3  3.4  0.8  0.5
# ..               ...  ..  ...  ...   ...  ...  ...  ...
# 95    Nikola Vucevic   C  0.3  6.1  10.4  2.8  1.0  1.0
# 96       Dwyane Wade  SG  0.8  6.2   4.5  3.8  1.4  0.7
# 97      Dion Waiters  SG  1.8  4.3   3.3  4.3  0.9  0.4
# 98  Hassan Whiteside   C  0.0  7.0  14.1  0.7  0.7  2.1
# 99      Lou Williams  SG  2.0  3.3   2.5  3.0  1.0  0.2
#
# [100 rows x 8 columns]

# %%
# value_counts() : 현재가지고 있는 데이터에서 먼저 포지션의 갯수를 확인
df.Pos.value_counts()
# Out:
# SG    50
# C     50
# Name: Pos, dtype: int64

# %% [markdown]
# # 데이터시각화
# - 데이터 특징을 바탕으로 한 공간에 시각화 함으로써, 우리는 머신러닝 학습에 필요한 특징과 불필요한 특징을 쉽게 구분지을 수 있다.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 스틸, 2점슛 데이터 시각화
sns.lmplot(x ='STL', y = '2P', data = df, fit_reg = False, # x축, y축, 데이터, 라인없음
               scatter_kws = {"s":150}, #좌표상의 점의 크기
               markers = ['o','x'],
               hue ='Pos') #예측값

#title
plt.title('STL and 2P in 2d place')
# Out:
# Text(0.5, 1.0, 'STL and 2P in 2d place')

# %%
# 어시스트, 2점슛 데이터 시각화
sns.lmplot(x ='AST', y = '2P', data = df, fit_reg = False, # x축, y축, 데이터, 라인없음
               scatter_kws = {"s":150}, #좌표상의 점의 크기
               markers = ['o','x'],
               hue ='Pos') #예측값

#title
plt.title('AST and 2P in 2d place')
# Out:
# Text(0.5, 1.0, 'AST and 2P in 2d place')

# %%
# 블록킹, 3점슛 데이터 시각화
sns.lmplot(x ='BLK', y = '3P', data = df, fit_reg = False, # x축, y축, 데이터, 라인없음
               scatter_kws = {"s":150}, #좌표상의 점의 크기
               markers = ['o','x'],
               hue ='Pos') #예측값

#title
plt.title('BLK and 3P in 2d place')
# Out:
# Text(0.5, 1.0, 'BLK and 3P in 2d place')

# %%
# 리바운드, 3점슛 데이터 시각화
sns.lmplot(x ='TRB', y = '3P', data = df, fit_reg = False, # x축, y축, 데이터, 라인없음
               scatter_kws = {"s":150}, #좌표상의 점의 크기
               markers = ['o','x'],
               hue ='Pos') #예측값

#title
plt.title('TRB and 3P in 2d place')
# Out:
# Text(0.5, 1.0, 'TRB and 3P in 2d place')

# %% [markdown]
# # 데이터 전처리

# %%
# 분별력이 없는 특징(feature)을 데이터에서 제거, 데이터 다듬기

df.drop(['2P','AST','STL'], axis = 1, inplace = True)
df.head()
# Out:
#            Player Pos   3P  TRB  BLK
# 0    Alex Abrines  SG  1.4  1.3  0.1
# 1    Steven Adams   C  0.0  7.7  1.0
# 2   Alexis Ajinca   C  0.0  4.5  0.6
# 3  Chris Andersen   C  0.0  2.6  0.6
# 4     Will Barton  SG  1.5  4.3  0.5

# %% [markdown]
# # 데이터 나누기 (학습데이터, 테스트데이터)

# %%
# scikit-learn library 설치
#!conda install scikit-learn

# %%
# 사이킷런의 train_test_split()을 사용하면 코드 한 줄로 쉽게 데이터를 나눌 수 있다.
from sklearn.model_selection import train_test_split

# 다듬어진 데이터에서 20%를 데스트 데이터로 분류. 
train_test_split(df, test_size=0.2)
# Out:
# [              Player Pos   3P   TRB  BLK
#  9    Bismack Biyombo   C  0.0   7.0  1.1
#  83       Jason Smith   C  0.5   3.5  0.7
#  89     Klay Thompson  SG  3.4   3.7  0.5
#  98  Hassan Whiteside   C  0.0  14.1  2.1
#  38      A.J. Hammons   C  0.2   1.6  0.6
#  ..               ...  ..  ...   ...  ...
#  28     Evan Fournier  SG  1.9   3.1  0.1
#  54    Frank Kaminsky   C  1.5   4.5  0.5
#  61       Brook Lopez   C  1.8   5.4  1.7
#  23     Anthony Davis   C  0.5  11.8  2.2
#  2      Alexis Ajinca   C  0.0   4.5  0.6
#
#  [80 rows x 5 columns],
#                        Player Pos   3P   TRB  BLK
#  91        Karl-Anthony Towns   C  1.2  12.3  1.3
#  97              Dion Waiters  SG  1.8   3.3  0.4
#  32             Manu Ginobili  SG  1.3   2.3  0.2
#  90          Tristan Thompson   C  0.0   9.2  1.1
#  55           Sean Kilpatrick  SG  1.5   4.0  0.1
#  81              Marcus Smart  SG  1.2   3.9  0.4
#  8           Patrick Beverley  SG  1.6   5.9  0.4
# ...

# %%
# 데이터를 train과 validation, test로 나누는 이유는
# train은 모델을 학습시키기 위한 데이터셋 (80% 중에 80%)
# vaildation은 학습이 이미 완료된 모델을 검증하기 위한 데이터셋(80% 중에 20%)
# test는 모델의 '최종 성능'을 평가하기 위한 데이터셋 (약 20%)

# %%
# 테스트 데이터의 갯수
test.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_104912\4131842641.py in <module>
#       1 # 테스트 데이터의 갯수
# ----> 2 test.shape[0]
#
# NameError: name 'test' is not defined

# %%
train.to_csv("data/csv/baskeball_train.csv", index= None)

# %%
test.to_csv("data/csv/baskeball_test.csv", index= None)
